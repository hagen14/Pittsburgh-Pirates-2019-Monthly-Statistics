# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pit_april = pd.read_csv("pit_batting_march_april.csv")
pit_may = pd.read_csv("pit_batting_may.csv")
pit_pos_salary = pd.read_csv("pit_batters_salaries_2019.csv")

# %%
pit_april
# Out:
#                Players     G    AB     R     H   2B   3B   HR   RBI    BB  \
# 0            Josh Bell  27.0  98.0  16.0  28.0  8.0  2.0  6.0  21.0  12.0
# 1        Melky Cabrera  26.0  85.0   8.0  28.0  5.0  0.0  3.0   7.0   3.0
# 2             JB Shuck  25.0  46.0   3.0   9.0  0.0  1.0  0.0   2.0   8.0
# 3          Colin Moran  25.0  56.0   5.0  15.0  3.0  0.0  2.0  11.0   7.0
# 4   Francisco Cervelli  24.0  80.0   9.0  14.0  2.0  0.0  1.0   4.0   6.0
# 5         Adam Frazier  24.0  93.0  13.0  24.0  5.0  0.0  1.0   6.0  10.0
# 6         Jung Ho Kang  24.0  75.0   5.0  12.0  3.0  0.0  4.0   8.0   6.0
# 7          Pablo Reyes  22.0  36.0   5.0   5.0  0.0  0.0  0.0   3.0   3.0
# 8         Jason Martin  17.0  35.0   3.0   8.0  2.0  0.0  0.0   2.0   3.0
# 9       Starling Marte  17.0  75.0   9.0  15.0  4.0  1.0  3.0  11.0   2.0
# 10       Erik Gonzalez  16.0  51.0   2.0  11.0  2.0  1.0  0.0   2.0   6.0
# 11         Cole Tucker  10.0  36.0   4.0   9.0  3.0  0.0  1.0   2.0   2.0
# ...

# %%
pit_april.drop(17, axis=0, inplace=True)
pit_april.drop(18, axis=0, inplace=True)
pit_april.drop(19, axis=0, inplace=True)
pit_april.drop(20, axis=0, inplace=True)
pit_april.drop(21, axis=0, inplace=True)
pit_april.drop(22, axis=0, inplace=True)
pit_april.drop(23, axis=0, inplace=True)
pit_april.drop(24, axis=0, inplace=True)
pit_april.drop(25, axis=0, inplace=True)
pit_april.drop(26, axis=0, inplace=True)
pit_april.drop(27, axis=0, inplace=True)
pit_april.drop(28, axis=0, inplace=True)
pit_april.drop(29, axis=0, inplace=True)
pit_april.drop(30, axis=0, inplace=True)
pit_april.drop(31, axis=0, inplace=True)
pit_april.drop(32, axis=0, inplace=True)
pit_april.drop(33, axis=0, inplace=True)
pit_april.drop(34, axis=0, inplace=True)
pit_april.drop(35, axis=0, inplace=True)
pit_april.drop(36, axis=0, inplace=True)
pit_april.drop(37, axis=0, inplace=True)
pit_april.drop(38, axis=0, inplace=True)
pit_april.drop(39, axis=0, inplace=True)
pit_april.drop(40, axis=0, inplace=True)
pit_april.drop(41, axis=0, inplace=True)

# %%
players_april = ['Bell, Josh', 'Cabrera, Melky', 'Shuck, JB', 'Moran, Colin', 'Cervelli, Francisco', 'Frazier, Adam', 'Kang, Jung Ho', 'Reyes, Pablo', 'Martin, Jason', 'Marte, Starling', 'Gonzalez, Erik', 'Tucker, Cole', 'Reynolds, Bryan', 'Polanco, Gregory', 'Diaz, Elias', 'Newman, Kevin', 'Stallings, Jason']

# %%
del pit_april['Players']

# %%
pit_april.index = players_april

# %%
pit_april
# Out:
#                         G    AB     R     H   2B   3B   HR   RBI    BB    SO  \
# Bell, Josh           27.0  98.0  16.0  28.0  8.0  2.0  6.0  21.0  12.0  27.0
# Cabrera, Melky       26.0  85.0   8.0  28.0  5.0  0.0  3.0   7.0   3.0  11.0
# Shuck, JB            25.0  46.0   3.0   9.0  0.0  1.0  0.0   2.0   8.0  10.0
# Moran, Colin         25.0  56.0   5.0  15.0  3.0  0.0  2.0  11.0   7.0  12.0
# Cervelli, Francisco  24.0  80.0   9.0  14.0  2.0  0.0  1.0   4.0   6.0  24.0
# Frazier, Adam        24.0  93.0  13.0  24.0  5.0  0.0  1.0   6.0  10.0  15.0
# Kang, Jung Ho        24.0  75.0   5.0  12.0  3.0  0.0  4.0   8.0   6.0  28.0
# Reyes, Pablo         22.0  36.0   5.0   5.0  0.0  0.0  0.0   3.0   3.0  14.0
# Martin, Jason        17.0  35.0   3.0   8.0  2.0  0.0  0.0   2.0   3.0  10.0
# Marte, Starling      17.0  75.0   9.0  15.0  4.0  1.0  3.0  11.0   2.0  16.0
# Gonzalez, Erik       16.0  51.0   2.0  11.0  2.0  1.0  0.0   2.0   6.0  13.0
# ...

# %%
april_totals = pit_april.sum(axis=0)

# %%
april_totals[2]
# Out:
# 88.0

# %%
april_games = 27
april_ab = april_totals[1]
april_runs = round(april_totals[2])
april_hits = round(april_totals[3])
april_2b = round(april_totals[4])
april_3b = round(april_totals[5])
april_hr = round(april_totals[6])
april_rbi = round(april_totals[7])
april_bb = round(april_totals[8])
april_so = round(april_totals[9])
april_sb = round(april_totals[10])
april_cs = round(april_totals[11])
april_hbp = april_totals[12]
april_sf = april_totals[13]
april_tb = april_totals[14]

# %%
april_avg = round(april_hits/april_ab, 3)
april_obp = round(((april_hits + april_bb + april_hbp)/(april_ab + april_bb + april_hbp + april_sf)), 3)
april_slg = round((april_tb/april_ab), 3)

# %%
april_ops = round((april_obp + april_slg), 3)

# %%
pit_may
# Out:
#                 Players   G   AB   R   H  2B  3B  HR  RBI  BB  SO  SB  CS  \
# 0            Bell, Josh  24   95  22  37   9   0  11   27  11  19   0   0
# 1       Marte, Starling  24  103  18  30   6   1   3   10   4  19   5   0
# 2         Frazier, Adam  23   99  14  25   4   1   2    7   2  11   0   1
# 3          Moran, Colin  23   70   5  20   3   0   2   12   4  23   0   0
# 4       Reynolds, Bryan  23   73  11  20   3   1   3   15   8  18   0   0
# 5        Cabrera, Melky  22   61   9  21   4   0   0    9   5   5   1   0
# 6      Polanco, Gregory  19   74  14  20   5   1   5   15   8  22   0   1
# 7          Tucker, Cole  20   54   5   6   1   0   1    4   3  17   0   0
# 8         Newman, Kevin  19   57   5  20   5   1   0    5   5  11   1   0
# 9           Diaz, Elias  18   59   1  16   1   0   0    5   4  12   0   0
# 10  Cervelli, Francisco  10   29   2   7   1   0   0    1   3   7   1   0
# 11        Kang, Jung Ho   7   15   1   0   0   0   0    0   2   3   0   0
# ...

# %%
players_may = ['Bell, Josh', 'Marte, Starling', 'Frazier, Adam', 'Moran, Colin', 'Reynolds, Bryan', 'Cabrera, Melky', 'Polanco, Gregory', 'Tucker, Cole', 'Newman, Kevin', 'Diaz, Elias', 'Cervelli, Francisco', 'Kang, Jung Ho', 'Elmore, Jake', 'Shuck, JB', 'Reyes, Pablo', 'Osuna, Jose']

# %%
pit_may.index = players_may

# %%
del pit_may['Players']

# %%
pit_may
# Out:
#                       G   AB   R   H  2B  3B  HR  RBI  BB  SO  SB  CS  HBP  \
# Bell, Josh           24   95  22  37   9   0  11   27  11  19   0   0    0
# Marte, Starling      24  103  18  30   6   1   3   10   4  19   5   0    3
# Frazier, Adam        23   99  14  25   4   1   2    7   2  11   0   1    2
# Moran, Colin         23   70   5  20   3   0   2   12   4  23   0   0    0
# Reynolds, Bryan      23   73  11  20   3   1   3   15   8  18   0   0    0
# Cabrera, Melky       22   61   9  21   4   0   0    9   5   5   1   0    1
# Polanco, Gregory     19   74  14  20   5   1   5   15   8  22   0   1    1
# Tucker, Cole         20   54   5   6   1   0   1    4   3  17   0   0    0
# Newman, Kevin        19   57   5  20   5   1   0    5   5  11   1   0    1
# Diaz, Elias          18   59   1  16   1   0   0    5   4  12   0   0    0
# Cervelli, Francisco  10   29   2   7   1   0   0    1   3   7   1   0    2
# ...

# %%
may_totals = pit_may.sum(axis=0)

# %%
may_totals
# Out:
# G      248.000
# AB     815.000
# R      108.000
# H      224.000
# 2B      42.000
# 3B       5.000
# HR      27.000
# RBI    110.000
# BB      59.000
# SO     170.000
# SB       8.000
# CS       2.000
# HBP     10.000
# SF       2.000
# TB     360.000
# AVG      4.131
# OBP      4.894
# SLG      5.834
# OPS     10.726
# dtype: float64

# %%
may_games = 24
may_ab = may_totals[1]
may_runs = round(may_totals[2])
may_hits = round(may_totals[3])
may_2b = round(may_totals[4])
may_3b = round(may_totals[5])
may_hr = round(may_totals[6])
may_rbi = round(may_totals[7])
may_bb = round(may_totals[8])
may_so = round(may_totals[9])
may_sb = round(may_totals[10])
may_cs = round(may_totals[11])
may_hbp = may_totals[12]
may_sf = may_totals[13]
may_tb = may_totals[14]

# %%
may_avg = round(may_hits/may_ab, 3)
may_obp = round(((may_hits + may_bb + may_hbp)/(may_ab + may_bb + may_hbp + may_sf)), 3)
may_slg = round((may_tb/may_ab), 3)

# %%
may_ops = round((may_obp + may_slg), 3)

# %%
total_games = april_games + may_games
total_runs = april_runs + may_runs
total_hits = april_hits + may_hits
total_2b = april_2b + may_2b
total_3b = april_3b + may_3b
total_hr = april_hr + may_hr
total_rbi = april_rbi + may_rbi
total_bb = april_bb + may_bb
total_so = april_so + may_so
total_sb = april_sb + may_sb
total_cs = april_cs + may_cs

# %%
total_avg = round(((total_hits/(april_ab + may_ab))), 3)
total_obp = round(((april_hits+may_hits)+(april_bb+may_bb)+(april_hbp+may_hbp))/((april_ab+may_ab)+(april_bb+may_bb)+(april_hbp+may_bb)+(april_sf+may_sf)),3)
total_slg = round((april_tb+may_tb)/(april_ab+may_ab),3)

# %%
total_ops = round((total_obp+total_slg),3)

# %%
teamStats = pd.DataFrame({'G': [april_games, may_games, total_games], 'R': [april_runs, may_runs, total_runs], 'H': [april_hits, may_hits, total_hits], '2B': [april_2b, may_2b, total_2b], '3B': [april_3b, may_3b, total_3b], 'HR': [april_hr, may_hr, total_hr], 'RBI': [april_rbi, may_rbi, total_rbi], 'BB': [april_bb, may_bb, total_bb], 'SO': [april_so, may_so, total_so], 'SB': [april_sb, may_sb, total_sb], 'CS': [april_cs, may_cs, total_cs], 'AVG': [april_avg, may_avg, total_avg], 'OBP': [april_obp, may_obp, total_obp], 'SLG': [april_slg, may_slg, total_slg], 'OPS': [april_ops, may_ops, total_ops]})
teamStats.index = ['March/April', 'May', 'Totals']

# %%
teamStats
# Out:
#               G      R      H    2B    3B    HR    RBI     BB     SO    SB  \
# March/April  27   88.0  204.0  45.0   5.0  22.0   83.0   72.0  212.0  12.0
# May          24  108.0  224.0  42.0   5.0  27.0  110.0   59.0  170.0   8.0
# Totals       51  196.0  428.0  87.0  10.0  49.0  193.0  131.0  382.0  20.0
#
#               CS    AVG    OBP    SLG    OPS
# March/April  4.0  0.238  0.301  0.379  0.680
# May          2.0  0.275  0.331  0.442  0.773
# Totals       6.0  0.256  0.307  0.409  0.716

# %%
teamAvgx = [april_avg, may_avg]
teamAvgx
# Out:
# [0.238, 0.275]

# %%
teamAvgdf = pd.DataFrame({'AVG': [april_avg, may_avg]})
teamAvgdf.index = ['March/April', 'May']
teamAvgdf
# Out:
#                AVG
# March/April  0.238
# May          0.275

# %%
teamAvg_fig = plt.plot(teamAvgdf,'y')
plt.title('Pirates Monthly Batting Average')
plt.xlabel('Month')
plt.ylabel('Batting Average')
# Out:
# Text(0,0.5,'Batting Average')

# %%
teamRBI = pd.DataFrame({'RBI': [april_rbi, may_rbi]})
teamRBI.index = ['March/April', 'May']
teamRBI
# Out:
#                RBI
# March/April   83.0
# May          110.0

# %%
teamRBI_fig = plt.plot(teamRBI,'y')
plt.title('Pirates Monthly RBIs')
plt.xlabel('Month')
plt.ylabel('RBIs')
# Out:
# Text(0,0.5,'RBIs')

# %%
march_april_RpG = teamStats.loc['March/April'][1]/teamStats.loc['March/April'][0]
may_RpG = teamStats.loc['May'][1]/teamStats.loc['May'][0]

# %%
teamRpG = pd.DataFrame({'Runs/Game': [round(march_april_RpG,1), round(may_RpG,1)]})

# %%
teamRpG.index = ['March/April', 'May']

# %%
teamRpG
# Out:
#              Runs/Game
# March/April        3.3
# May                4.7

# %%
teamRpGplot = teamRpG.plot.bar(title='Pirates Monthly Runs/Game Totals', rot=0)

# %%
jbellG = pit_april.loc['Bell, Josh'][0] + pit_may.loc['Bell, Josh'][0]
jbellAB = pit_april.loc['Bell, Josh'][1] + pit_may.loc['Bell, Josh'][1]
jbellR = pit_april.loc['Bell, Josh'][2] + pit_may.loc['Bell, Josh'][2]
jbellH = pit_april.loc['Bell, Josh'][3] + pit_may.loc['Bell, Josh'][3]
jbell2b = pit_april.loc['Bell, Josh'][4] + pit_may.loc['Bell, Josh'][4]
jbell3b = pit_april.loc['Bell, Josh'][5] + pit_may.loc['Bell, Josh'][5]
jbellHR = pit_april.loc['Bell, Josh'][6] + pit_may.loc['Bell, Josh'][6]
jbellRBI = pit_april.loc['Bell, Josh'][7] + pit_may.loc['Bell, Josh'][7]
jbellBB = pit_april.loc['Bell, Josh'][8] + pit_may.loc['Bell, Josh'][8]
jbellSO = pit_april.loc['Bell, Josh'][9] + pit_may.loc['Bell, Josh'][9]
jbellSB = pit_april.loc['Bell, Josh'][10] + pit_may.loc['Bell, Josh'][10]
jbellCS = pit_april.loc['Bell, Josh'][11] + pit_may.loc['Bell, Josh'][11]
jbellHBP = pit_april.loc['Bell, Josh'][12] + pit_may.loc['Bell, Josh'][12]
jbellSF = pit_april.loc['Bell, Josh'][13] + pit_may.loc['Bell, Josh'][13]
jbellTB = pit_april.loc['Bell, Josh'][14] + pit_may.loc['Bell, Josh'][14]
jbellAVG = round((pit_april.loc['Bell, Josh'][3] + pit_may.loc['Bell, Josh'][3])/(pit_april.loc['Bell, Josh'][1] + pit_may.loc['Bell, Josh'][1]), 3)

smarteG = pit_april.loc['Marte, Starling'][0] + pit_may.loc['Marte, Starling'][0]
smarteAB = pit_april.loc['Marte, Starling'][1] + pit_may.loc['Marte, Starling'][1]
smarteR = pit_april.loc['Marte, Starling'][2] + pit_may.loc['Marte, Starling'][2]
smarteH = pit_april.loc['Marte, Starling'][3] + pit_may.loc['Marte, Starling'][3]
smarte2b = pit_april.loc['Marte, Starling'][4] + pit_may.loc['Marte, Starling'][4]
smarte3b = pit_april.loc['Marte, Starling'][5] + pit_may.loc['Marte, Starling'][5]
smarteHR = pit_april.loc['Marte, Starling'][6] + pit_may.loc['Marte, Starling'][6]
smarteRBI = pit_april.loc['Marte, Starling'][7] + pit_may.loc['Marte, Starling'][7]
smarteBB = pit_april.loc['Marte, Starling'][8] + pit_may.loc['Marte, Starling'][8]
smarteSO = pit_april.loc['Marte, Starling'][9] + pit_may.loc['Marte, Starling'][9]
smarteSB = pit_april.loc['Marte, Starling'][10] + pit_may.loc['Marte, Starling'][10]
smarteCS = pit_april.loc['Marte, Starling'][11] + pit_may.loc['Marte, Starling'][11]
smarteHBP = pit_april.loc['Marte, Starling'][12] + pit_may.loc['Marte, Starling'][12]
smarteSF = pit_april.loc['Marte, Starling'][13] + pit_may.loc['Marte, Starling'][13]
smarteTB = pit_april.loc['Marte, Starling'][14] + pit_may.loc['Marte, Starling'][14]
smarteAVG = round((pit_april.loc['Marte, Starling'][3] + pit_may.loc['Marte, Starling'][3])/(pit_april.loc['Marte, Starling'][1] + pit_may.loc['Marte, Starling'][1]), 3)

gpolancoG = pit_april.loc['Polanco, Gregory'][0] + pit_may.loc['Polanco, Gregory'][0]
gpolancoAB = pit_april.loc['Polanco, Gregory'][1] + pit_may.loc['Polanco, Gregory'][1]
gpolancoR = pit_april.loc['Polanco, Gregory'][2] + pit_may.loc['Polanco, Gregory'][2]
gpolancoH = pit_april.loc['Polanco, Gregory'][3] + pit_may.loc['Polanco, Gregory'][3]
gpolanco2b = pit_april.loc['Polanco, Gregory'][4] + pit_may.loc['Polanco, Gregory'][4]
gpolanco3b = pit_april.loc['Polanco, Gregory'][5] + pit_may.loc['Polanco, Gregory'][5]
gpolancoHR = pit_april.loc['Polanco, Gregory'][6] + pit_may.loc['Polanco, Gregory'][6]
gpolancoRBI = pit_april.loc['Polanco, Gregory'][7] + pit_may.loc['Polanco, Gregory'][7]
gpolancoBB = pit_april.loc['Polanco, Gregory'][8] + pit_may.loc['Polanco, Gregory'][8]
gpolancoSO = pit_april.loc['Polanco, Gregory'][9] + pit_may.loc['Polanco, Gregory'][9]
gpolancoSB = pit_april.loc['Polanco, Gregory'][10] + pit_may.loc['Polanco, Gregory'][10]
gpolancoCS = pit_april.loc['Polanco, Gregory'][11] + pit_may.loc['Polanco, Gregory'][11]
gpolancoHBP = pit_april.loc['Polanco, Gregory'][12] + pit_may.loc['Polanco, Gregory'][12]
gpolancoSF = pit_april.loc['Polanco, Gregory'][13] + pit_may.loc['Polanco, Gregory'][13]
gpolancoTB = pit_april.loc['Polanco, Gregory'][14] + pit_may.loc['Polanco, Gregory'][14]
gpolancoAVG = round((pit_april.loc['Polanco, Gregory'][3] + pit_may.loc['Polanco, Gregory'][3])/(pit_april.loc['Polanco, Gregory'][1] + pit_may.loc['Polanco, Gregory'][1]), 3)

mcabreraG = pit_april.loc['Cabrera, Melky'][0] + pit_may.loc['Cabrera, Melky'][0]
mcabreraAB = pit_april.loc['Cabrera, Melky'][1] + pit_may.loc['Cabrera, Melky'][1]
mcabreraR = pit_april.loc['Cabrera, Melky'][2] + pit_may.loc['Cabrera, Melky'][2]
mcabreraH = pit_april.loc['Cabrera, Melky'][3] + pit_may.loc['Cabrera, Melky'][3]
mcabrera2b = pit_april.loc['Cabrera, Melky'][4] + pit_may.loc['Cabrera, Melky'][4]
mcabrera3b = pit_april.loc['Cabrera, Melky'][5] + pit_may.loc['Cabrera, Melky'][5]
mcabreraHR = pit_april.loc['Cabrera, Melky'][6] + pit_may.loc['Cabrera, Melky'][6]
mcabreraRBI = pit_april.loc['Cabrera, Melky'][7] + pit_may.loc['Cabrera, Melky'][7]
mcabreraBB = pit_april.loc['Cabrera, Melky'][8] + pit_may.loc['Cabrera, Melky'][8]
mcabreraSO = pit_april.loc['Cabrera, Melky'][9] + pit_may.loc['Cabrera, Melky'][9]
mcabreraSB = pit_april.loc['Cabrera, Melky'][10] + pit_may.loc['Cabrera, Melky'][10]
mcabreraCS = pit_april.loc['Cabrera, Melky'][11] + pit_may.loc['Cabrera, Melky'][11]
mcabreraCS = pit_april.loc['Cabrera, Melky'][12] + pit_may.loc['Cabrera, Melky'][12]
mcabreraCS = pit_april.loc['Cabrera, Melky'][13] + pit_may.loc['Cabrera, Melky'][13]
mcabreraCS = pit_april.loc['Cabrera, Melky'][14] + pit_may.loc['Cabrera, Melky'][14]
mcabreraAVG = round((pit_april.loc['Cabrera, Melky'][3] + pit_may.loc['Cabrera, Melky'][3])/(pit_april.loc['Cabrera, Melky'][1] + pit_may.loc['Cabrera, Melky'][1]), 3)

breynoldsG = pit_april.loc['Reynolds, Bryan'][0] + pit_may.loc['Reynolds, Bryan'][0]
breynoldsAB = pit_april.loc['Reynolds, Bryan'][1] + pit_may.loc['Reynolds, Bryan'][1]
breynoldsR = pit_april.loc['Reynolds, Bryan'][2] + pit_may.loc['Reynolds, Bryan'][2]
breynoldsH = pit_april.loc['Reynolds, Bryan'][3] + pit_may.loc['Reynolds, Bryan'][3]
breynolds2b = pit_april.loc['Reynolds, Bryan'][4] + pit_may.loc['Reynolds, Bryan'][4]
breynolds3b = pit_april.loc['Reynolds, Bryan'][5] + pit_may.loc['Reynolds, Bryan'][5]
breynoldsHR = pit_april.loc['Reynolds, Bryan'][6] + pit_may.loc['Reynolds, Bryan'][6]
breynoldsRBI = pit_april.loc['Reynolds, Bryan'][7] + pit_may.loc['Reynolds, Bryan'][7]
breynoldsBB = pit_april.loc['Reynolds, Bryan'][8] + pit_may.loc['Reynolds, Bryan'][8]
breynoldsSO = pit_april.loc['Reynolds, Bryan'][9] + pit_may.loc['Reynolds, Bryan'][9]
breynoldsSB = pit_april.loc['Reynolds, Bryan'][10] + pit_may.loc['Reynolds, Bryan'][10]
breynoldsCS = pit_april.loc['Reynolds, Bryan'][11] + pit_may.loc['Reynolds, Bryan'][11]
breynoldsCS = pit_april.loc['Reynolds, Bryan'][12] + pit_may.loc['Reynolds, Bryan'][12]
breynoldsCS = pit_april.loc['Reynolds, Bryan'][13] + pit_may.loc['Reynolds, Bryan'][13]
breynoldsCS = pit_april.loc['Reynolds, Bryan'][14] + pit_may.loc['Reynolds, Bryan'][14]
breynoldsAVG = round((pit_april.loc['Reynolds, Bryan'][3] + pit_may.loc['Reynolds, Bryan'][3])/(pit_april.loc['Reynolds, Bryan'][1] + pit_may.loc['Reynolds, Bryan'][1]), 3)

afrazierG = pit_april.loc['Frazier, Adam'][0] + pit_may.loc['Frazier, Adam'][0]
afrazierAB = pit_april.loc['Frazier, Adam'][1] + pit_may.loc['Frazier, Adam'][1]
afrazierR = pit_april.loc['Frazier, Adam'][2] + pit_may.loc['Frazier, Adam'][2]
afrazierH = pit_april.loc['Frazier, Adam'][3] + pit_may.loc['Frazier, Adam'][3]
afrazier2b = pit_april.loc['Frazier, Adam'][4] + pit_may.loc['Frazier, Adam'][4]
afrazier3b = pit_april.loc['Frazier, Adam'][5] + pit_may.loc['Frazier, Adam'][5]
afrazierHR = pit_april.loc['Frazier, Adam'][6] + pit_may.loc['Frazier, Adam'][6]
afrazierRBI = pit_april.loc['Frazier, Adam'][7] + pit_may.loc['Frazier, Adam'][7]
afrazierBB = pit_april.loc['Frazier, Adam'][8] + pit_may.loc['Frazier, Adam'][8]
afrazierSO = pit_april.loc['Frazier, Adam'][9] + pit_may.loc['Frazier, Adam'][9]
afrazierSB = pit_april.loc['Frazier, Adam'][10] + pit_may.loc['Frazier, Adam'][10]
afrazierCS = pit_april.loc['Frazier, Adam'][11] + pit_may.loc['Frazier, Adam'][11]
afrazierCS = pit_april.loc['Frazier, Adam'][12] + pit_may.loc['Frazier, Adam'][12]
afrazierCS = pit_april.loc['Frazier, Adam'][13] + pit_may.loc['Frazier, Adam'][13]
afrazierCS = pit_april.loc['Frazier, Adam'][14] + pit_may.loc['Frazier, Adam'][14]
afrazierAVG = round((pit_april.loc['Frazier, Adam'][3] + pit_may.loc['Frazier, Adam'][3])/(pit_april.loc['Frazier, Adam'][1] + pit_may.loc['Frazier, Adam'][1]), 3)

cmoranG = pit_april.loc['Moran, Colin'][0] + pit_may.loc['Moran, Colin'][0]
cmoranAB = pit_april.loc['Moran, Colin'][1] + pit_may.loc['Moran, Colin'][1]
cmoranR = pit_april.loc['Moran, Colin'][2] + pit_may.loc['Moran, Colin'][2]
cmoranH = pit_april.loc['Moran, Colin'][3] + pit_may.loc['Moran, Colin'][3]
cmoran2b = pit_april.loc['Moran, Colin'][4] + pit_may.loc['Moran, Colin'][4]
cmoran3b = pit_april.loc['Moran, Colin'][5] + pit_may.loc['Moran, Colin'][5]
cmoranHR = pit_april.loc['Moran, Colin'][6] + pit_may.loc['Moran, Colin'][6]
cmoranRBI = pit_april.loc['Moran, Colin'][7] + pit_may.loc['Moran, Colin'][7]
cmoranBB = pit_april.loc['Moran, Colin'][8] + pit_may.loc['Moran, Colin'][8]
cmoranSO = pit_april.loc['Moran, Colin'][9] + pit_may.loc['Moran, Colin'][9]
cmoranSB = pit_april.loc['Moran, Colin'][10] + pit_may.loc['Moran, Colin'][10]
cmoranCS = pit_april.loc['Moran, Colin'][11] + pit_may.loc['Moran, Colin'][11]
cmoranCS = pit_april.loc['Moran, Colin'][12] + pit_may.loc['Moran, Colin'][12]
cmoranCS = pit_april.loc['Moran, Colin'][13] + pit_may.loc['Moran, Colin'][13]
cmoranCS = pit_april.loc['Moran, Colin'][14] + pit_may.loc['Moran, Colin'][14]
cmoranAVG = round((pit_april.loc['Moran, Colin'][3] + pit_may.loc['Moran, Colin'][3])/(pit_april.loc['Moran, Colin'][1] + pit_may.loc['Moran, Colin'][1]), 3)

# %%
teamIndStats = pd.DataFrame({'G': [jbellG, smarteG, gpolancoG, mcabreraG, breynoldsG, afrazierG, cmoranG], 'AB': [jbellAB, smarteAB, gpolancoAB, mcabreraAB, breynoldsAB, afrazierAB, cmoranAB], 'R': [jbellR, smarteR, gpolancoR, mcabreraR, breynoldsR, afrazierR, cmoranR], 'H': [jbellH, smarteH, gpolancoH, mcabreraH, breynoldsH, afrazierH, cmoranH], '2B': [jbell2b, smarte2b, gpolanco2b, mcabrera2b, breynolds2b, afrazier2b, cmoran2b], '3B': [jbell3b, smarte3b, gpolanco3b, mcabrera3b, breynolds3b, afrazier3b, cmoran3b], 'HR': [jbellHR, smarteHR, gpolancoHR, mcabreraHR, breynoldsHR, afrazierHR, cmoranHR], 'RBI': [jbellRBI, smarteRBI, gpolancoRBI, mcabreraRBI, breynoldsRBI, afrazierRBI, cmoranRBI], 'BB': [jbellBB, smarteBB, gpolancoBB, mcabreraBB, breynoldsBB, afrazierBB, cmoranBB], 'SO': [jbellSO, smarteSO, gpolancoSO, mcabreraSO, breynoldsSO, afrazierSO, cmoranSO], 'SB': [jbellSB, smarteSB, gpolancoSB, mcabreraSB, breynoldsSB, afrazierSB, cmoranSB], 'CS': [jbellCS, smarteCS, gpolancoCS, mcabreraCS, breynoldsCS, afrazierCS, cmoranCS], 'AVG': [jbellAVG, smarteAVG, gpolancoAVG, mcabreraAVG, breynoldsAVG, afrazierAVG, cmoranAVG]})
teamIndStats.index = ['Josh Bell', 'Starling Marte', 'Gregory Polanco', 'Melky Cabrera', 'Bryan Reynolds', 'Adam Frazier', 'Colin Moran']

# %%
teamIndStats
# Out:
#                     G     AB     R     H    2B   3B    HR   RBI    BB    SO  \
# Josh Bell        51.0  193.0  38.0  65.0  17.0  2.0  17.0  48.0  23.0  46.0
# Starling Marte   41.0  178.0  27.0  45.0  10.0  2.0   6.0  21.0   6.0  35.0
# Gregory Polanco  26.0  100.0  16.0  27.0   6.0  1.0   5.0  15.0  11.0  28.0
# Melky Cabrera    48.0  146.0  17.0  49.0   9.0  0.0   3.0  16.0   8.0  16.0
# Bryan Reynolds   31.0   99.0  13.0  31.0   8.0  1.0   4.0  16.0   8.0  24.0
# Adam Frazier     47.0  192.0  27.0  49.0   9.0  1.0   3.0  13.0  12.0  26.0
# Colin Moran      48.0  126.0  10.0  35.0   6.0  0.0   4.0  23.0  11.0  35.0
#
#                   SB    CS    AVG
# Josh Bell        0.0   1.0  0.337
# Starling Marte   8.0   1.0  0.253
# Gregory Polanco  0.0   1.0  0.270
# Melky Cabrera    2.0  67.0  0.336
# Bryan Reynolds   0.0  56.0  0.313
# Adam Frazier     2.0  69.0  0.255
# Colin Moran      0.0  53.0  0.278

# %%
highsalaryAVG = pd.DataFrame({'AVG': [smarteAVG, gpolancoAVG, mcabreraAVG]})
highsalaryAVG.index = ['Starling Marte','Gregory Polanco','Melky Cabrera']
minimumsalaryAVG = pd.DataFrame({'AVG': [jbellAVG, breynoldsAVG, afrazierAVG, cmoranAVG]})
minimumsalaryAVG.index = ['Josh Bell', 'Bryan Reynolds', 'Adam Frazier', 'Colin Moran']
highsalaryAVG
# Out:
#                    AVG
# Starling Marte   0.253
# Gregory Polanco  0.270
# Melky Cabrera    0.336

# %%
minimumsalaryAVG
# Out:
#                   AVG
# Josh Bell       0.337
# Bryan Reynolds  0.313
# Adam Frazier    0.255
# Colin Moran     0.278

# %%
highsalaryAVG_fig = plt.plot(highsalaryAVG,'yo')
plt.title('PIT Batting Averages (Players Salary Over $1.0M)')
plt.xlabel('Player')
plt.ylabel('Batting Average')
# Out:
# Text(0,0.5,'Batting Average')

# %%
minimumAVG_fig = plt.plot(minimumsalaryAVG,'yo')
plt.title('PIT Batting Averages (Players Salary Under $1.0M)')
plt.xlabel('Player')
plt.ylabel('Batting Average')
# Out:
# Text(0,0.5,'Batting Average')

# %%
indRBI = pd.DataFrame({'RBI/G': [round(jbellRBI/jbellG, 3), round(smarteRBI/smarteG, 3), round(gpolancoRBI/gpolancoG, 3), round(mcabreraRBI/mcabreraG, 3), round(breynoldsRBI/breynoldsG, 3)]})
indRBI.index = ['Josh Bell','Starling Marte','Gregory Polanco','Melky Cabrera', 'Bryan Reynolds']
indRBI
# Out:
#                  RBI/G
# Josh Bell        0.941
# Starling Marte   0.512
# Gregory Polanco  0.577
# Melky Cabrera    0.333
# Bryan Reynolds   0.516

# %%
indRBI_fig = plt.plot(indRBI,'yo')
plt.title('PIT Individual Stats (RBI per Game)')
plt.xlabel('Player')
plt.ylabel('RBI/G')
# Out:
# Text(0,0.5,'RBI/G')

# %%
pit_pos_salary.index = ['Francisco Cervelli', 'Corey Dickerson', 'Gregory Polanco', 'Starling Marte', 'Jung Ho Kang', 'Lonnie Chisenhall', 'Melky Cabrera', 'Josh Bell', 'Adam Frazier', 'Colin Moran', 'Elias Diaz', 'Erik Gonzalez', 'Kevin Newman', 'Jake Elmore', 'Cole Tucker', 'Bryan Reynolds']
del pit_pos_salary['Players']

# %%
pit_pos_salary_read = pit_pos_salary['Str Salary ($)']
pit_pos_salary_int = pit_pos_salary['Int Salary']

# %%
pit_pos_salary_read
# Out:
# Francisco Cervelli    $10,333,333
# Corey Dickerson        $8,500,000
# Gregory Polanco        $7,000,000
# Starling Marte         $5,166,667
# Jung Ho Kang           $3,000,000
# Lonnie Chisenhall      $2,750,000
# Melky Cabrera          $1,150,000
# Josh Bell                $587,000
# Adam Frazier             $584,000
# Colin Moran              $579,500
# Elias Diaz               $578,500
# Erik Gonzalez            $577,000
# Kevin Newman             $557,500
# Jake Elmore              $555,000
# Cole Tucker              $555,000
# Bryan Reynolds           $555,000
# Name: Str Salary ($), dtype: object

# %%
pit_salary_2019 = pit_pos_salary_int.plot.barh(title="PIT Position Players 2019 Salaries", rot=0)
