# %%
import csv
import numpy as np
import pandas as pd

# %%
pit_ind = pd.read_csv("pit_batting.csv")

# %%
pit_ind
# Out:
#                 Player   G   PA   AB   R   H  2B  3B  HR  RBI  SB  CS  BB  SO  \
# 0   Francisco Cervelli  33  122  108  11  20   3   0   1    5   1   0   9  31
# 1            Josh Bell  47  201  177  35  60  15   2  16   47   0   1  21  44
# 2         Adam Frazier  43  189  174  24  43   8   1   2   11   2   2  12  25
# 3          Cole Tucker  26   86   80   8  13   3   0   2    5   0   0   5  27
# 4         Jung Ho Kang  31   98   90   6  12   3   0   4    8   0   0   8  31
# 5       Bryan Reynolds  27   89   81   9  26   8   0   4   12   0   0   8  19
# 6       Starling Marte  37  172  164  26  40   9   2   5   19   8   1   3  32
# 7      Gregory Polanco  23   99   90  16  25   5   1   5   13   0   1   8  19
# 8        Melky Cabrera  45  147  138  14  46   9   0   3   15   2   0   8  16
# 9          Colin Moran  44  126  114   9  29   5   0   4   22   0   0  11  31
# 10          Elias Diaz  19   64   61   7  16   1   0   0    3   0   0   3  10
# ...

# %%
index_ = ['Francisco Cervelli','Josh Bell','Adam Frazier','Cole Tucker','Jung Ho Kang','Bryan Reynolds','Starling Marte','Gregory Polanco','Melky Cabrera','Colin Moran','Elias Diaz','Kevin Newman']

# %%
pit_ind.index = index_

# %%
del pit_ind['Player']

# %%
pit_ind
# Out:
#                      G   PA   AB   R   H  2B  3B  HR  RBI  SB  CS  BB  SO  \
# Francisco Cervelli  33  122  108  11  20   3   0   1    5   1   0   9  31
# Josh Bell           47  201  177  35  60  15   2  16   47   0   1  21  44
# Adam Frazier        43  189  174  24  43   8   1   2   11   2   2  12  25
# Cole Tucker         26   86   80   8  13   3   0   2    5   0   0   5  27
# Jung Ho Kang        31   98   90   6  12   3   0   4    8   0   0   8  31
# Bryan Reynolds      27   89   81   9  26   8   0   4   12   0   0   8  19
# Starling Marte      37  172  164  26  40   9   2   5   19   8   1   3  32
# Gregory Polanco     23   99   90  16  25   5   1   5   13   0   1   8  19
# Melky Cabrera       45  147  138  14  46   9   0   3   15   2   0   8  16
# Colin Moran         44  126  114   9  29   5   0   4   22   0   0  11  31
# Elias Diaz          19   64   61   7  16   1   0   0    3   0   0   3  10
# Kevin Newman        21   60   53   4  18   4   1   0    6   1   0   6  13
#
# ...

# %%
tuckerAvg = pit_ind.loc['Cole Tucker'][13]

# %%
tuckerAvg
# Out:
# 0.163

# %%
teamAvg = pit_ind["BA"].mean()

# %%
teamAvg
# Out:
# 0.25825000000000004
